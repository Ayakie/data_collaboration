# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cntr_svm = [float(i) for i in "0.726 0.814 0.848 0.861 0.875 0.88  0.889 0.893 0.897 0.903".split()]
ind_svm = [float(i) for i in "0.594 0.594 0.594 0.594 0.594 0.594 0.594 0.594 0.594 0.594".split()]
dc_knn = [float(i) for i in "0.565 0.694 0.744 0.771 0.787 0.8   0.808 0.818 0.826 0.833".split()]
dc_svm = [float(i) for i in "0.551 0.772 0.823 0.848 0.864 0.873 0.882 0.885 0.887 0.892".split()]
dc_mlp = []

# %%
plt.figure(figsize=(15,5))
plt.plot(cntr_svm, color='grey', linestyle='-.', label='Centralized data analysis')
plt.plot(ind_svm, color='grey', linestyle='--', label='Individual data analysis')
plt.plot(dc_knn, label='DC-knn, knn=6, nanc=500, dd=50')
plt.plot(dc_svm, label='DC-svm, C=10, nanc=500, dd=50')
#plt.plot(fl, label='Federated Learning')
plt.ylabel('Accuracy')
plt.xlabel('Amount of data / Number of partitions')
locs, labels = plt.xticks()
plt.xticks(np.arange(0, 10, step = 1), ('100/1', '200/2', '300/3', '400/4', '500/5', '600/6', '700/7',
                                       '800/8', '900/9', '1000/10'))
plt.title("Accuracy (Mnist)")
plt.legend()

# %%
dc_svm = [float(i) for i in "0.551 0.772 0.823 0.848 0.864 0.873 0.882 0.885 0.887 0.892".split()]
dc_svm
# Out:
# [0.551, 0.772, 0.823, 0.848, 0.864, 0.873, 0.882, 0.885, 0.887, 0.892]

# %%
dc_svm
# Out:
# []
