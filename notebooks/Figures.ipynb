# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cntr_mlp = [float(i) for i in "0.703 0.805 0.837 0.858 0.874 0.883 0.89  0.894 0.9   0.905".split()]
ind_mlp = [float(i) for i in "0.703 0.703 0.703 0.703 0.703 0.703 0.703 0.703 0.703 0.703".split()]
dc_mlp = [float(i) for i in "0.716 0.79  0.825 0.845 0.853 0.866 0.875 0.876 0.883 0.884".split()]
dc_knn = [float(i) for i in "0.565 0.671 0.717 0.752 0.771 0.79  0.799 0.804 0.815 0.82".split()]
dc_svm = [float(i) for i in "0.604 0.779 0.818 0.845 0.862 0.876 0.882 0.89  0.894 0.898".split()]
dc_svm_SVD = [float(i) for i in "0.546 0.769 0.82  0.848 0.864 0.875 0.882 0.886 0.892 0.894".split()]
fl_mlp = [float(i) for i in "0.645 0.71  0.811 0.834 0.857 0.853 0.861 0.887 0.89  0.889".split()]

# %%
plt.figure(figsize=(15,5))
plt.plot(cntr_svm, color='grey', linestyle='-.', label='Centralized data analysis')
#plt.plot(ind_svm, color='grey', linestyle='--', label='Individual data analysis')
#plt.plot(dc_knn, label='DC-knn, knn=5, nanc=500, dd=50')
plt.plot(dc_svm, linestyle=':', label='DC-svm, C=10, PCA, dd=50')
#plt.plot(dc_svm_SVD, label='DC-svm-svd, C=10, nanc=500, dd=50')
plt.plot(dc_mlp, label='DC-mlp, adam, PCA, dd=50')
plt.plot(fl_mlp, linestyle='--', label='Federated Learning, 1E32B')
#plt.plot(fl, label='Federated Learning')
plt.ylabel('Accuracy')
plt.xlabel('Amount of data / Number of users')
locs, labels = plt.xticks()
plt.xticks(np.arange(0, 10, step = 1), ('100/1', '200/2', '300/3', '400/4', '500/5', '600/6', '700/7',
                                       '800/8', '900/9', '1000/10'))
plt.title("Accuracy (Mnist)")
plt.legend()

# %%
cntr_mlp = [float(i) for i in "0.588 0.725 0.777 0.811 0.827 0.843 0.855 0.865 0.867 0.874".split()]
ind_mlp = [float(i) for i in "0.588 0.588 0.588 0.588 0.588 0.588 0.588 0.588 0.588 0.588".split()]
dc_mlp = [float(i) for i in "0.618 0.692 0.734 0.768 0.777 0.788 0.795 0.81  0.812 0.82".split()]
dc_knn = [float(i) for i in "0.456 0.582 0.635 0.659 0.692 0.704 0.716 0.729 0.742 0.746".split()]
dc_svm = [float(i) for i in "0.418 0.652 0.711 0.76  0.78  0.807 0.815 0.829 0.832 0.839".split()]
fl_mlp = [float(i) for i in "0.649 0.664 0.672 0.727 0.733 0.744 0.782 0.82  0.789 0.806".split()]

# %%
plt.figure(figsize=(15,5))
plt.plot(cntr_svm, color='grey', linestyle='-.', label='Centralized data analysis')
#plt.plot(ind_svm, color='grey', linestyle='--', label='Individual data analysis')
#plt.plot(dc_knn, label='DC-knn, knn=5, nanc=500, dd=50')
plt.plot(dc_svm, linestyle=':', label='DC-svm, C=10, PCA, dd=50')
#plt.plot(dc_svm_SVD, label='DC-svm-svd, C=10, nanc=500, dd=50')
plt.plot(dc_mlp, label='DC-mlp, adam, PCA, dd=50')
plt.plot(fl_mlp, linestyle='--', label='Federated Learning, 1E32B')
plt.ylabel('Accuracy')
plt.xlabel('Amount of data / Number of users')
locs, labels = plt.xticks()
plt.xticks(np.arange(0, 10, step = 1), ('50/1', '100/2', '150/3', '200/4', '250/5', '300/6', '350/7',
                                       '400/8', '450/9', '500/10'))
plt.title("Accuracy (Mnist)")
plt.legend()
